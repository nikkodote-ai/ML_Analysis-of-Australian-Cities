# %% [markdown]
# # **Sydney vs. Melbourne**
#
#
# ---
#
#
# ##**Introduction**
# ### For a long time, there has always been a heated debate about which Australian city is better, Sydney  or Melbourne. So much so that the capital of this continent country is **NOT** either of the two, but is located **between** them (see the map) as a compromise and probably to avoid civil unrest.
#
#
# <br>
#
# ---
#
# <br>
#
# ##**Business Problem** <br>
# ### I'm not brave enough to settle this dispute, but this project aims to give the reader an idea of the Sydney and Melbourne's landscape. It can be useful to people who are at at the fork of making a decision to move to the biggest cities in Australia depending on their current need and interest. So which city is for you?

# %% [markdown]
# ## 1.) Import libraries

# %%
#for data analysis
import numpy as np
import pandas as pd

#for getting geo data
from geopy.geocoders import Nominatim

#for machine learning  - clustering
from sklearn.cluster import KMeans

#for data visualization

import matplotlib.cm as cm
import matplotlib.colors as colors

#for webscraping and handling requests
import requests
from bs4 import BeautifulSoup

from pandas.io.json import json_normalize

#filtering results of webscraping
import re

#map rendering
import folium

# %% [markdown]
# 2.)Webscraping the suburb names of Melbourne

# %%
#get request
melb_url = 'https://en.m.wikipedia.org/wiki/List_of_Melbourne_suburbs'
melb_results = requests.get(melb_url).content

#Parse the html data to beautifulsoup object
soup = BeautifulSoup(melb_results, 'html.parser')

#Initialize an empty list of the suburbs
melb_suburbs = []

#Append the suburb data from the BeautifulSoup object to the list

# %%
#the html contents are not formatted in a table; the suburbs are contained in bullets <li>
suburb_raw = []
for i in range(1,5):
  for row in soup.find('div', class_='mw-parser-output').find('section', class_='mf-section-{} collapsible-block'.format(i)).find_all('ul'):
    for j in row.find_all('li'):
       suburb_raw.append(j.get_text())

#using regex to only choose the ones with postal code in it. D means not digit, limited to 35 letters to exclude sentences.  
#Parentheses return the a tuple of 2 items (surburb (\D{0,35}), and postal(\d+)
suburb_pattern = re.compile(r'^(\D{0,35})(\d+)')



#after a lot of trial and error , loop, regex, pandas combo worked
melb_data =pd.DataFrame(columns=['Suburb', 'Postal Code', 'Query'])
for item in suburb_raw:
  item = suburb_pattern.findall(item)
  if item != []:
    query = ' '.join(item[0])
    suburb = item[0][0]
    postal = item[0][1]
    melb_data = melb_data.append({'Suburb': suburb, 'Postal Code': postal, 'Query': query}, ignore_index= True)

# %%
melb_data.head()
# Out:
#             Suburb Postal Code                 Query
# 0         Carlton         3053         Carlton  3053
# 1   Carlton North         3054   Carlton North  3054
# 2       Docklands         3008       Docklands  3008
# 3  East Melbourne         3002  East Melbourne  3002
# 4      Flemington         3031      Flemington  3031

# %%
#find the suburbs that contain parenthesis, then replace them in the 
exclude = re.compile('(\D*)(\(\D*\))  (\d+)')
exclude_list = []
exclude_post = []
exclude_suburb = []

for i in melb_data.Query:
  item = exclude.findall(i)
  if item != []:
    exclude_list.append(item)
    exclude_post.append(item[0][2])
    exclude_suburb.append(item[0][0])
print(exclude_list)
print(exclude_post)
print(exclude_suburb )
# Out:
# [[('Malvern ', '(/ˈmɔːlvən/)', '3144')], [('Prahran ', "(/pɛ'ræn/)", '3181')]]
# ['3144', '3181']
# ['Malvern ', 'Prahran ']

# %%
melb_data[melb_data['Postal Code'].isin(exclude_post)]
# Out:
#                     Suburb Postal Code                       Query
# 483               Kooyong         3144               Kooyong  3144
# 484  Malvern (/ˈmɔːlvən/)         3144  Malvern (/ˈmɔːlvən/)  3144
# 486    Prahran (/pɛ'ræn/)         3181    Prahran (/pɛ'ræn/)  3181
# 489               Windsor         3181               Windsor  3181

# %%
melb_data['Query'].replace(to_replace = ['Malvern (/ˈmɔːlvən/)  3144', 'Prahran (/pɛ\'ræn/)  3181'], value = ['Malvern 3144', 'Prahran 3181'], inplace = True)

# %%
melb_data.iloc[484:487,] #to check if the query is renamed. it will be used to get the coordinates for geocoder
# Out:
#                     Suburb Postal Code               Query
# 484  Malvern (/ˈmɔːlvən/)         3144        Malvern 3144
# 485          Malvern East         3145  Malvern East  3145
# 486    Prahran (/pɛ'ræn/)         3181        Prahran 3181

# %%
#@title Trial to get coordinates
#Geopy got a bit unreliable. one time it worked perfectly, the next, it timed out. so proceed to plan B
'''geolocator = Nominatim(user_agent="ML_explorer")

melb_data['Query'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))

melb_data['Coord']= melb_data['Query'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))

# Split the coordinates into Lat and Long, drop the M
melb_data[['Latitude', 'Longitude']] =melb_data['Coord'].apply(pd.Series)
'''
# Out:
# 'geolocator = Nominatim(user_agent="ML_explorer")\n\nmelb_data[\'Query\'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))\n\nmelb_data[\'Coord\']= melb_data[\'Query\'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))\n\n# Split the coordinates into Lat and Long, drop the M\nmelb_data[[\'Latitude\', \'Longitude\']] =melb_data[\'Coord\'].apply(pd.Series)\n'

# %%
# !pip install geocoder
import geocoder
# Out:
# Requirement already satisfied: geocoder in /usr/local/lib/python3.7/dist-packages (1.38.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from geocoder) (0.16.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->geocoder) (2021.5.30)

# %%
def get_latlng(suburb):
    # initialize your lat_lng_coords to None; making a function will help handle the timed out error
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Melbourne, Australia'.format(suburb))
        lat_lng_coords = g.latlng
    return lat_lng_coords
# Call the function to get the coordinates, store in a new list using list comprehension
coords = [ get_latlng(suburb) for suburb in melb_data["Suburb"].tolist()]

# %%
# Create temporary dataframe to populate the coordinates into Latitude and Longitude
temp = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
# Merge the coordinates into the original dataframe
melb_data['Latitude'] = temp['Latitude']
melb_data['Longitude'] = temp['Longitude']
melb_data.head()
# Out:
#             Suburb Postal Code                 Query  Latitude  Longitude
# 0         Carlton         3053         Carlton  3053 -37.80101  144.96951
# 1   Carlton North         3054   Carlton North  3054 -37.78918  144.97188
# 2       Docklands         3008       Docklands  3008 -37.81926  144.94555
# 3  East Melbourne         3002  East Melbourne  3002 -37.81132  144.97799
# 4      Flemington         3031      Flemington  3031 -37.78814  144.92965

# %%
melb_merged = melb_data.groupby('Postal Code')['Suburb'].apply(lambda s: ",".join(s)).to_frame().reset_index()
melb_merged
# Out:
#     Postal Code                                             Suburb
# 0          3000                                         Melbourne
# 1          3002                                    East Melbourne
# 2          3003                                    West Melbourne
# 3          3004                              Melbourne ,Melbourne
# 4          3006    Southbank ,South Wharf ,Southbank ,South Wharf
# ..          ...                                                ...
# 241        3978                      Cardinia ,Clyde ,Clyde North
# 242        3980                    Blind Bight ,Tooradin ,Warneet
# 243        3981  Bayles ,Catani ,Dalmore ,Heath Hill ,Koo Wee Rup
# 244        3984                 Caldermeade ,Lang Lang ,Monomeith
# 245        3987                                             Nyora
#
# [246 rows x 2 columns]

# %% [markdown]
# # PART 3
# ## **DATA ANALYSIS**
#
# Data Analysis Melbourne

# %%
address_MEL = "Melbourne, VIC"
location_mel = geocoder.arcgis(address_MEL)
latitude_mel = location_mel.latlng[0]
longitude_mel = location_mel.latlng[1]
print('Melbourne\'s coordinates are : Latitude ( {} ) , Longitude ( {} )'.format(latitude_mel, longitude_mel))
# Out:
# Melbourne's coordinates are : Latitude ( -37.81738999999993 ) , Longitude ( 144.96751000000006 )

# %%
map_melbourne = folium.Map(location = [latitude_mel, longitude_mel], zoom_start= 10)

for lat, lng, combined in zip(melb_data['Latitude'],melb_data['Longitude'], melb_data['Query']):
  label = folium.Popup(combined, parse_html=True)
  folium.CircleMarker(
      location = [lat,lng],
      radius = 5,
      popup = label,
      color = 'blue',
      fill = True,
      fill_color = '#14B6B0',
      fill_opacity = 0.6,
      parse_html = False).add_to(map_melbourne)

map_melbourne
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_c4dcda0eb5fb4976b020cd0196548f67%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c4dcda0eb5fb4976b020cd0196548f67%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_c4dcda0eb5fb4976b020cd0196548f67%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_c4dcda0eb5fb4976b020cd0196548f67%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-37.81738999999993%2C%20144.96751000000006%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_585c437e3c6a4218a95ac691736c9673%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C% ...

# %%
melb_merged.head()
# Out:
#   Postal Code                                           Suburb
# 0        3000                                       Melbourne
# 1        3002                                  East Melbourne
# 2        3003                                  West Melbourne
# 3        3004                            Melbourne ,Melbourne
# 4        3006  Southbank ,South Wharf ,Southbank ,South Wharf

# %% [markdown]
# # **3. Explore using Foursquare API**

# %%
#@title CREDENTIALS
#credentials
CLIENT_ID = 'EA1V0LWDFSZ13O0GV0S5ZRBCP1MKEC150VKEAXWWZPTOJMCV' 
CLIENT_SECRET = '5OM21UMNWI5NF4OC42FLHH3HITXMMWBOJWIRHP34OUWDJNEA'
VERSION = '20210101'
LIMIT = 100

# %% [markdown]
# Explore neighborhood

# %%
'''url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&limit={}&ll={},{},&radius={}'.format(CLIENT_ID, CLIENT_SECRET,VERSION,LIMIT,latitude_mel,longitude_mel,500)
  #in that order (CLIENT_ID, CLIENT_SECRET,VERSION,LIMIT,latitude_mel,longitude_mel,500)
results = requests.get(url).json()
results'''

# %%
'''melb_venues = getNearbyVenues(suburbs = melb_data['Suburb'], latitudes= melb_data['Latitude'], longitudes = melb_data['Longitude'], radius= 500)
melb_venues'''

# %%
def getNearbyvenues(names, latitudes, longitudes, radius = 500):
  venues_list= [] #initialize an empty list
  for name, lat, lng in zip(names, latitudes, longitudes): #for loop to take the data of interest then appending them in the initialized list, venues_list
    #print(name)

    #create the API request url
    url = "https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&LIMIT={}&ll={},{}&radius={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        LIMIT,
        lat,
        lng,
        radius
    )

    #make the request
    results=  requests.get(url).json()['response']['groups'][0]['items']

    #return only the relevant information for each nearby venues
    venues_list.append([(
        name,
        lat,
        lng,
        v['venue']['name'],
        v['venue']['location']['lat'],
        v['venue']['location']['lng'],
        v['venue']['categories'][0]['name']) for v in results #list comprehesion to take out values from results
        ])
  nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list]) #list comprehension; unpack items in venue list to package in a dataframe
  nearby_venues.columns = ['Neighborhood',
                            'Neighborhood Latitude',
                            'Neighborhood Longitude',
                            'Venue',
                            'Venue Latitude',
                            'Venue Longitude',
                            'Venue Category'
                            
                            ] #renaming column names
  
  return(nearby_venues)

# %%
melb_venues = getNearbyvenues(names = melb_merged['Suburb'], latitudes = melb_merged['Latitude'], longitudes = melb_merged['Longitude'], radius = 500)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-1b83c060f584> in <module>()
# ----> 1 melb_venues = getNearbyvenues(names = melb_merged['Suburb'], latitudes = melb_merged['Latitude'], longitudes = melb_merged['Longitude'], radius = 500)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Latitude'

# %%
melb_venues
# Out:
#      Neighborhood  Neighborhood Latitude  ...  Venue Longitude   Venue Category
# 0        Carlton               -37.80101  ...       144.968490      Pizza Place
# 1        Carlton               -37.80101  ...       144.968610         Wine Bar
# 2        Carlton               -37.80101  ...       144.967480     Gourmet Shop
# 3        Carlton               -37.80101  ...       144.967290      Coffee Shop
# 4        Carlton               -37.80101  ...       144.968499           Bakery
# ...           ...                    ...  ...              ...              ...
# 4290     Windsor               -37.85616  ...       144.993124       Restaurant
# 4291     Windsor               -37.85616  ...       144.987911              Pub
# 4292     Windsor               -37.85616  ...       144.992947             Café
# 4293     Windsor               -37.85616  ...       144.992931  Thai Restaurant
# 4294     Windsor               -37.85616  ...       144.993171             Café
#
# [4295 rows x 7 columns]

# %%
#Exploratory Data Analysis

print ('There are {} unique categories'.format(len(melb_venues['Venue Category'])))
# Out:
# There are 4295 unique categories

# %%
#Analyzing each neighborhood

melb_onehot = pd.get_dummies(melb_venues[['Venue Category']], prefix = "", prefix_sep="")

# %%
#add neighborhood column back to onehot dataframe
melb_onehot['Suburb'] = melb_data['Suburb']

#put the Suburb column to first
suburb_col = melb_onehot.pop('Suburb')
melb_onehot.insert(0, 'Suburb', suburb_col)

#have a quick look at the columns
melb_onehot.head()
# Out:
#             Suburb  Adult Boutique  ...  Xinjiang Restaurant  Yoga Studio
# 0         Carlton                0  ...                    0            0
# 1   Carlton North                0  ...                    0            0
# 2       Docklands                0  ...                    0            0
# 3  East Melbourne                0  ...                    0            0
# 4      Flemington                0  ...                    0            0
#
# [5 rows x 315 columns]

# %%
#group by suburb then get mean of frequency

melb_grouped = melb_onehot.groupby('Suburb').mean().reset_index()
melb_grouped.tail()
# Out:
#               Suburb  Adult Boutique  ...  Xinjiang Restaurant  Yoga Studio
# 442  Yarra Junction              0.0  ...                  0.0          0.0
# 443       Yarrambat              0.0  ...                  0.0          0.0
# 444       Yellingbo              0.0  ...                  0.0          0.0
# 445          Yering              0.0  ...                  0.0          0.0
# 446          Yuroke              0.0  ...                  0.0          0.0
#
# [5 rows x 315 columns]

# %%
#confirm size
melb_grouped.shape
# Out:
# (447, 315)

# %%
num_top_venues = 5
for sub in melb_grouped['Suburb']:
  #print suburb on top
  print('**' + sub + '**')

  #select the corresponding suburb then transpose data to categories line up vertically
  temp = melb_grouped[melb_grouped['Suburb'] == sub].T.reset_index()
  
  temp.columns = ['Venues', 'Frequency']

  #Neighborhood is the row, the succeeding ones are Venues and Frequency
  temp = temp.iloc[1:]
  temp['Frequency'] = temp['Frequency'].astype(float)
  temp = temp.round({'Frequency': 2})

  #sort the values of the transposed data by frequency in descendin order then print the top venues
  print(temp.sort_values('Frequency', ascending=False).reset_index(drop = True).head(num_top_venues))
  print ('\n')
# Out:
# **Abbotsford **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Albert Park **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Alphington **
#                   Venues  Frequency
# 0                   Café        0.5
# 1  Vietnamese Restaurant        0.5
# 2         Adult Boutique        0.0
# 3                 Office        0.0
# 4   Outdoor Supply Store        0.0
#
#
# **Armadale **
#                  Venues  Frequency
# 0              Tea Room        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Arthurs Seat **
#                  Venues  Frequency
# 0           Music Venue        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Ashburton **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Ashwood **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Aspendale **
#                  Venues  Frequency
# 0    Frozen Yogurt Shop        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Aspendale Gardens **
#                  Venues  Frequency
# 0          Burger Joint        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Attwood **
#                  Venues  Frequency
# 0            Steakhouse        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Avonsleigh **
#                  Venues  Frequency
# 0        History Museum        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Badger Creek **
#                  Venues  Frequency
# 0                   Pub        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Balaclava **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Balnarring **
#                  Venues  Frequency
# 0    Spanish Restaurant        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Balnarring Beach **
#                  Venues  Frequency
# 0            Art Museum        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Balwyn **
#                  Venues  Frequency
# 0                   Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Balwyn North **
#                  Venues  Frequency
# 0          Burger Joint        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Bangholme **
#                  Venues  Frequency
# 0         Deli / Bodega        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Baxter **
#                  Venues  Frequency
# 0            Whisky Bar        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Bayles **
#                  Venues  Frequency
# 0  Arts & Entertainment        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Bayswater **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Bayswater North **
#                  Venues  Frequency
# 0              Tea Room        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Beaconsfield **
#                  Venues  Frequency
# 0    Spanish Restaurant        0.5
# 1                  Café        0.5
# 2        Adult Boutique        0.0
# 3                Office        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Beaconsfield Upper **
#                  Venues  Frequency
# 0   Sporting Goods Shop        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Beaumaris **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Beenak **
#                  Venues  Frequency
# 0      Malay Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Belgrave **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Belgrave Heights **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Belgrave South **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Bellfield **
#                  Venues  Frequency
# 0                   Pub        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Bend of Islands **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Bentleigh **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Bentleigh East **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Berwick **
#                           Venues  Frequency
# 0                   Cocktail Bar        1.0
# 1                    Pastry Shop        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Beveridge **
#                  Venues  Frequency
# 0                   Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Big Pats Creek **
#                           Venues  Frequency
# 0              Convenience Store        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Bittern **
#                  Venues  Frequency
# 0                  Road        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Black Rock **
#                  Venues  Frequency
# 0           Beer Garden        1.0
# 1         Moving Target        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Blackburn **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Blackburn North **
#                  Venues  Frequency
# 0               Theater        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Blackburn South **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Blairgowrie **
#                           Venues  Frequency
# 0              Convenience Store        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Blind Bight **
#                  Venues  Frequency
# 0  Himalayan Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Bonbeach **
#                   Venues  Frequency
# 0  Australian Restaurant        1.0
# 1         Adult Boutique        0.0
# 2                   Park        0.0
# 3            Outlet Mall        0.0
# 4   Outdoor Supply Store        0.0
#
#
# **Boneo **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Boronia **
#                  Venues  Frequency
# 0              Creperie        1.0
# 1                Office        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Botanic Ridge **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Box Hill **
#                  Venues  Frequency
# 0                   Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Box Hill North **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Box Hill South **
#                  Venues  Frequency
# 0        Sandwich Place        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Braeside **
#                  Venues  Frequency
# 0            Bagel Shop        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Briar Hill **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Brighton **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Brighton East **
#                Venues  Frequency
# 0  Seafood Restaurant        0.5
# 1                Café        0.5
# 2      Adult Boutique        0.0
# 3                Park        0.0
# 4         Outlet Mall        0.0
#
#
# **Broadmeadows **
#                  Venues  Frequency
# 0            Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Brunswick **
#                  Venues  Frequency
# 0               Theater        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Brunswick East **
#                  Venues  Frequency
# 0              Wine Bar        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Brunswick West **
#                           Venues  Frequency
# 0                   Cocktail Bar        1.0
# 1                    Pastry Shop        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Bulla **
#                  Venues  Frequency
# 0                  Park        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Bulleen **
#                  Venues  Frequency
# 0                   Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Bundoora **
#                  Venues  Frequency
# 0           Coffee Shop       0.33
# 1           Supermarket       0.33
# 2                  Café       0.33
# 3                Office       0.00
# 4  Outdoor Supply Store       0.00
#
#
# **Bunyip **
#                  Venues  Frequency
# 0         Grocery Store        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Bunyip North **
#                           Venues  Frequency
# 0                 Clothing Store        1.0
# 1                 Adult Boutique        0.0
# 2                    Pastry Shop        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Burnley **
#                   Venues  Frequency
# 0  Australian Restaurant        1.0
# 1         Adult Boutique        0.0
# 2                   Park        0.0
# 3            Outlet Mall        0.0
# 4   Outdoor Supply Store        0.0
#
#
# **Burwood **
#            Venues  Frequency
# 0     Salad Place        0.5
# 1            Café        0.5
# 2  Adult Boutique        0.0
# 3            Park        0.0
# 4     Outlet Mall        0.0
#
#
# **Burwood East **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Bylands **
#              Venues  Frequency
# 0  Malay Restaurant        0.5
# 1              Café        0.5
# 2    Adult Boutique        0.0
# 3         Multiplex        0.0
# 4       Outlet Mall        0.0
#
#
# **Caldermeade **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cambarville **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Camberwell **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Campbellfield **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cannons Creek **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Canterbury **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cape Schanck **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Capel Sound **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Cardinia **
#                   Venues  Frequency
# 0  Australian Restaurant        1.0
# 1         Adult Boutique        0.0
# 2                   Park        0.0
# 3            Outlet Mall        0.0
# 4   Outdoor Supply Store        0.0
#
#
# **Carlton **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Carlton North **
#                  Venues  Frequency
# 0              Wine Bar        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Carnegie **
#                           Venues  Frequency
# 0                   Tram Station        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Carrum **
#                           Venues  Frequency
# 0                 Breakfast Spot        1.0
# 1                           Park        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Carrum Downs **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Catani **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Caulfield **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Caulfield East **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Caulfield North **
#                  Venues  Frequency
# 0     Indian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Caulfield South **
#                  Venues  Frequency
# 0  Fast Food Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Chadstone **
#                      Venues  Frequency
# 0  Mediterranean Restaurant        1.0
# 1            Adult Boutique        0.0
# 2                    Office        0.0
# 3      Outdoor Supply Store        0.0
# 4         Outdoor Sculpture        0.0
#
#
# **Chelsea **
#                  Venues  Frequency
# 0          Dessert Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Chelsea Heights **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Cheltenham **
#               Venues  Frequency
# 0  Health Food Store        0.5
# 1         Restaurant        0.5
# 2     Adult Boutique        0.0
# 3             Office        0.0
# 4        Outlet Mall        0.0
#
#
# **Chirnside Park **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Christmas Hills **
#                  Venues  Frequency
# 0      Asian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Chum Creek **
#                           Venues  Frequency
# 0                          Track        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Clarinda **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Clarkefield **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Clayton **
#                  Venues  Frequency
# 0                   Pub        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Clayton South **
#                  Venues  Frequency
# 0      Sushi Restaurant        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Clematis **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Clifton Hill **
#                  Venues  Frequency
# 0               Dog Run        1.0
# 1                  Park        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Clyde **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Clyde North **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Coburg **
#                           Venues  Frequency
# 0                   Cocktail Bar        0.5
# 1                Thai Restaurant        0.5
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Coburg North **
#                           Venues  Frequency
# 0                    Coffee Shop        0.5
# 1             Italian Restaurant        0.5
# 2                         Office        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Cockatoo **
#                           Venues  Frequency
# 0                 Clothing Store        1.0
# 1                 Adult Boutique        0.0
# 2                    Pastry Shop        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Coldstream **
#                  Venues  Frequency
# 0                Garden        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Collingwood **
#                           Venues  Frequency
# 0             Chinese Restaurant        1.0
# 1                 Adult Boutique        0.0
# 2                    Pastry Shop        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Coolaroo **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cora Lynn **
#                  Venues  Frequency
# 0             Bookstore        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cottles Bridge **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Craigieburn **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Cranbourne **
#                   Venues  Frequency
# 0  Indonesian Restaurant        1.0
# 1           Noodle House        0.0
# 2   Outdoor Supply Store        0.0
# 3      Outdoor Sculpture        0.0
# 4      Other Repair Shop        0.0
#
#
# **Cranbourne East **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cranbourne North **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cranbourne South **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Cranbourne West **
#                  Venues  Frequency
# 0    African Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Cremorne **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Crib Point **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Croydon **
#                  Venues  Frequency
# 0          Gourmet Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Croydon Hills **
#                  Venues  Frequency
# 0                Museum        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Croydon North **
#                  Venues  Frequency
# 0                 Plaza        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Croydon South **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dallas **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dalmore **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dandenong **
#                  Venues  Frequency
# 0      Malay Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Dandenong North **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dandenong South **
#                           Venues  Frequency
# 0                 Breakfast Spot        1.0
# 1                           Park        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Deepdene **
#                  Venues  Frequency
# 0   Fried Chicken Joint        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Devon Meadows **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dewhurst **
#                  Venues  Frequency
# 0             Wine Shop        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Diamond Creek **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Diggers Rest **
#                  Venues  Frequency
# 0                Garden        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Dingley Village **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dixons Creek **
#                  Venues  Frequency
# 0                Lounge        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Docklands **
#                  Venues  Frequency
# 0          Gourmet Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Don Valley **
#                  Venues  Frequency
# 0    Athletics & Sports        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Doncaster **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Doncaster East **
#                  Venues  Frequency
# 0      Asian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Donnybrook **
#                  Venues  Frequency
# 0     Fish & Chips Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Donvale **
#                  Venues  Frequency
# 0        Sandwich Place        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Doreen **
#                  Venues  Frequency
# 0                   Pub        0.5
# 1   Japanese Restaurant        0.5
# 2        Adult Boutique        0.0
# 3          Noodle House        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Doveton **
#                  Venues  Frequency
# 0          Burger Joint        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Dromana **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Eaglemont **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **East Melbourne **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Eden Park **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Edithvale **
#                           Venues  Frequency
# 0  Vegetarian / Vegan Restaurant        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Elsternwick **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Eltham **
#                  Venues  Frequency
# 0                   Pub        0.5
# 1                 Hotel        0.5
# 2        Adult Boutique        0.0
# 3          Noodle House        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Eltham North **
#                  Venues  Frequency
# 0          Burger Joint        0.5
# 1           Flower Shop        0.5
# 2        Adult Boutique        0.0
# 3                Office        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Elwood **
#                  Venues  Frequency
# 0             Bookstore        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Emerald **
#                  Venues  Frequency
# 0   Lebanese Restaurant        1.0
# 1                Office        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Endeavour Hills **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Epping **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Eumemmerring **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Fairfield **
#                  Venues  Frequency
# 0                   Pub        0.5
# 1     Fish & Chips Shop        0.5
# 2        Adult Boutique        0.0
# 3                Office        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Fawkner **
#                  Venues  Frequency
# 0     Indian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Fernshaw **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Ferntree Gully **
#                  Venues  Frequency
# 0            Street Art        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Ferny Creek **
#                           Venues  Frequency
# 0                    College Gym        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Fingal **
#                  Venues  Frequency
# 0               Theater        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Fitzroy **
#                  Venues  Frequency
# 0  Gym / Fitness Center        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Fitzroy North **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Flemington **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Flinders **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Forest Hill **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Frankston **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Frankston North **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Frankston South **
#                  Venues  Frequency
# 0        Farmers Market        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Gardenvale **
#                  Venues  Frequency
# 0       Thai Restaurant        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Garfield **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Garfield North **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Gembrook **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Gilderoy **
#                           Venues  Frequency
# 0              Convenience Store        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Gladstone Park **
#                  Venues  Frequency
# 0               Stadium        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Gladysdale **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Glen Huntly **
#                  Venues  Frequency
# 0    Seafood Restaurant        1.0
# 1                Office        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Glen Iris **
#                  Venues  Frequency
# 0                  Café        0.5
# 1          Gourmet Shop        0.5
# 2        Adult Boutique        0.0
# 3         Moving Target        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Glen Waverley **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Glenroy **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Gowanbrae **
#                  Venues  Frequency
# 0    Mexican Restaurant        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Greensborough **
#                 Venues  Frequency
# 0        Deli / Bodega        0.5
# 1  Japanese Restaurant        0.5
# 2       Adult Boutique        0.0
# 3               Office        0.0
# 4          Outlet Mall        0.0
#
#
# **Greenvale **
#                  Venues  Frequency
# 0              Building        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Gruyere **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Guys Hill **
#                  Venues  Frequency
# 0   Szechuan Restaurant        1.0
# 1         Movie Theater        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **HMAS Cerberus **
#                  Venues  Frequency
# 0                   Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Hadfield **
#                  Venues  Frequency
# 0          Dessert Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Hallam **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Hampton **
#                  Venues  Frequency
# 0           Outlet Mall        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Hampton East **
#                  Venues  Frequency
# 0          Burger Joint        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Hampton Park **
#                           Venues  Frequency
# 0          Performing Arts Venue        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Harkaway **
#                  Venues  Frequency
# 0                   Pub        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Hastings **
#                  Venues  Frequency
# 0              Creperie        1.0
# 1                Office        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Hawthorn **
#                  Venues  Frequency
# 0                  Park        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Hawthorn East **
#                  Venues  Frequency
# 0       Thai Restaurant        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Healesville **
#                  Venues  Frequency
# 0         Go Kart Track        1.0
# 1        Adult Boutique        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Heath Hill **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Heatherton **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Heathmont **
#                  Venues  Frequency
# 0                  Road        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Heidelberg **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Heidelberg Heights **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Heidelberg West **
#                  Venues  Frequency
# 0         Grocery Store        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Highett **
#                  Venues  Frequency
# 0       Harbor / Marina        0.5
# 1                  Café        0.5
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Hoddles Creek **
#                  Venues  Frequency
# 0            Boxing Gym        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Hughesdale **
# ...
#
#
# **St Kilda West **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Steels Creek **
#                  Venues  Frequency
# 0   Japanese Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Strathewen **
#                           Venues  Frequency
# 0                       Pharmacy        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Sunbury **
#                  Venues  Frequency
# 0                   Pub        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Surrey Hills **
#                  Venues  Frequency
# 0                  Road        0.5
# 1    Italian Restaurant        0.5
# 2          Noodle House        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tarrawarra **
#                           Venues  Frequency
# 0                         Casino        1.0
# 1                Organic Grocery        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Tecoma **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Templestowe **
#                   Venues  Frequency
# 0  Vietnamese Restaurant        1.0
# 1         Adult Boutique        0.0
# 2           Noodle House        0.0
# 3   Outdoor Supply Store        0.0
# 4      Outdoor Sculpture        0.0
#
#
# **Templestowe Lower **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **The Basin **
#                  Venues  Frequency
# 0                   Bar        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **The Patch **
#                           Venues  Frequency
# 0                      Pet Store        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Thomastown **
#                  Venues  Frequency
# 0  Fast Food Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Thornbury **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Three Bridges **
#                  Venues  Frequency
# 0             Multiplex        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Tonimbuk **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tooradin **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tooradin North **
#                           Venues  Frequency
# 0             Chinese Restaurant        1.0
# 1                 Adult Boutique        0.0
# 2                    Pastry Shop        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Toorak **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Toorongo **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tootgarook **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tremont **
#                  Venues  Frequency
# 0    Italian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tuerong **
#                           Venues  Frequency
# 0               Pedestrian Plaza        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Tullamarine **
#                  Venues  Frequency
# 0                  Park        0.5
# 1           Supermarket        0.5
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Tyabb **
#                  Venues  Frequency
# 0      Asian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Tynong **
#                  Venues  Frequency
# 0    Seafood Restaurant        1.0
# 1                Office        0.0
# 2           Outlet Mall        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Tynong North **
#                  Venues  Frequency
# 0             Multiplex        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Upper Ferntree Gully **
#                  Venues  Frequency
# 0           Sports Club        0.5
# 1                Bakery        0.5
# 2        Adult Boutique        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Upwey **
#                       Venues  Frequency
# 0  Middle Eastern Restaurant        1.0
# 1             Adult Boutique        0.0
# 2               Noodle House        0.0
# 3       Outdoor Supply Store        0.0
# 4          Outdoor Sculpture        0.0
#
#
# **Vermont **
#                  Venues  Frequency
# 0            Art Museum        0.5
# 1      Pedestrian Plaza        0.5
# 2        Adult Boutique        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Vermont South **
#                  Venues  Frequency
# 0              Tea Room        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Vervale **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Viewbank **
#                  Venues  Frequency
# 0       Thai Restaurant        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Wandin East **
#                  Venues  Frequency
# 0            Steakhouse        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Wandin North **
#                  Venues  Frequency
# 0                Bakery        1.0
# 1        Adult Boutique        0.0
# 2         Moving Target        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Wantirna **
#                  Venues  Frequency
# 0               Theater        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Wantirna South **
#                  Venues  Frequency
# 0        Ice Cream Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Warburton **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Warburton East **
#                  Venues  Frequency
# 0               Theater        1.0
# 1        Adult Boutique        0.0
# 2         Movie Theater        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Warneet **
#                  Venues  Frequency
# 0            Playground        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Warrandyte **
#                  Venues  Frequency
# 0      Asian Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Warrandyte South **
#                  Venues  Frequency
# 0              Boutique        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Warranwood **
#                  Venues  Frequency
# 0            Whisky Bar        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Waterways **
#                           Venues  Frequency
# 0                 Breakfast Spot        1.0
# 1                           Park        0.0
# 2  Paper / Office Supplies Store        0.0
# 3                    Outlet Mall        0.0
# 4           Outdoor Supply Store        0.0
#
#
# **Watsonia **
#                           Venues  Frequency
# 0                   Tram Station        1.0
# 1                 Adult Boutique        0.0
# 2  Paper / Office Supplies Store        0.0
# 3           Outdoor Supply Store        0.0
# 4              Outdoor Sculpture        0.0
#
#
# **Watsonia North **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Watsons Creek **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Wattle Glen **
#                  Venues  Frequency
# 0      Malay Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Wesburn **
#                  Venues  Frequency
# 0     French Restaurant        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **West Melbourne **
#                           Venues  Frequency
# 0                    Coffee Shop        1.0
# 1                 Adult Boutique        0.0
# 2                Organic Grocery        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Westmeadows **
#                  Venues  Frequency
# 0                  Park        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Wheelers Hill **
#                  Venues  Frequency
# 0     Fish & Chips Shop        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
#
#
# **Whittlesea **
#                           Venues  Frequency
# 0                    Pizza Place        1.0
# 1  Paper / Office Supplies Store        0.0
# 2           Outdoor Supply Store        0.0
# 3              Outdoor Sculpture        0.0
# 4              Other Repair Shop        0.0
#
#
# **Wildwood **
#                  Venues  Frequency
# 0         Deli / Bodega        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Windsor **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Wollert **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Wonga Park **
#                  Venues  Frequency
# 0                   Bar        0.5
# 1             Bookstore        0.5
# 2        Adult Boutique        0.0
# 3                Office        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Woodstock **
#                  Venues  Frequency
# 0                  Park        1.0
# 1          Noodle House        0.0
# 2  Outdoor Supply Store        0.0
# 3     Outdoor Sculpture        0.0
# 4     Other Repair Shop        0.0
#
#
# **Woori Yallock **
#                  Venues  Frequency
# 0  Cantonese Restaurant        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yallambie **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yan Yean **
#                  Venues  Frequency
# 0                   Pub        0.5
# 1          Dessert Shop        0.5
# 2        Adult Boutique        0.0
# 3          Noodle House        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yannathan **
#                  Venues  Frequency
# 0                  Café        1.0
# 1        Adult Boutique        0.0
# 2       Organic Grocery        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yarra Glen **
#                  Venues  Frequency
# 0                 Hotel        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yarra Junction **
#                   Venues  Frequency
# 0  Australian Restaurant        1.0
# 1         Adult Boutique        0.0
# 2                   Park        0.0
# 3            Outlet Mall        0.0
# 4   Outdoor Supply Store        0.0
#
#
# **Yarrambat **
#                  Venues  Frequency
# 0        Sandwich Place        1.0
# 1        Adult Boutique        0.0
# 2                  Park        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yellingbo **
#                           Venues  Frequency
# 0                 Clothing Store        1.0
# 1                 Adult Boutique        0.0
# 2                    Pastry Shop        0.0
# 3  Paper / Office Supplies Store        0.0
# 4                    Outlet Mall        0.0
#
#
# **Yering **
#                  Venues  Frequency
# 0   Japanese Restaurant        1.0
# 1        Adult Boutique        0.0
# 2                Office        0.0
# 3           Outlet Mall        0.0
# 4  Outdoor Supply Store        0.0
#
#
# **Yuroke **
#                  Venues  Frequency
# 0              Wine Bar        1.0
# 1        Adult Boutique        0.0
# 2          Noodle House        0.0
# 3  Outdoor Supply Store        0.0
# 4     Outdoor Sculpture        0.0
